# %% [markdown]
# # EMPLOYEE ATTRITION - IBM HR DATA - EDA

# %%
# -- IMPORT LIBS
import plotly.tools as tls
import plotly.graph_objs as go
import pandas as pd
import numpy as np
import seaborn as sns
from seaborn import clustermap
import matplotlib.pyplot as plt

from IPython.display import display
from pandas import DataFrame as dfm
# Import statements required for Plotly
# Plotly is used to get details when hovered
import plotly.offline as py
py.init_notebook_mode(connected=True)
# --

# -- IMPORT FILE
IBM_HR = pd.read_csv('HR-Employee-Attrition.csv')
#IBM_HR = pd.read_csv('HR-Attrition-upsampled-cleaned.csv')
# --
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
"""
# -- DROP COLS FOR PLOTTING
notused = ['DailyRate', 'EmployeeNumber', 'EmployeeCount',
           'MonthlyIncome', 'MonthlyRate', 'Over18'
           # list any Column labels you don't want displayed
           ]
df1 = IBM_HR
for i in notused:
    df1.drop(labels=[i], axis=1,
             inplace=True
             )
"""

df1 = IBM_HR
# --
# -- PLOT VARIABLES
df1cols = [i for i in df1.columns]
display(df1cols)
for i in df1cols:
    pd.crosstab(df1[i], df1['Attrition']).plot(kind='bar',
                                               fontsize=22,
                                               figsize=(20, 10)
                                               )
    plt.xlabel(xlabel=i, size=32)
# --

# -- DROP FOR CROSS TABS
"""
notused = ['DailyRate', 'EmployeeNumber', 'EmployeeCount',
           # 'MonthlyIncome',
           'MonthlyRate', 'Over18'
           # list any Column labels you don't want displayed
           ]
"""
df2 = IBM_HR
"""
for i in notused:
    df2.drop(labels=[i], axis=1,
             inplace=True
             )
"""

# Review cols
df2cols = [i for i in df2.columns]
# --

# -- ITERATE THROUGH THE DATAFRAME AND FIND HIGHEST AND LOWEST RATIOS OF ATTRITION
for i in df2cols:
    dfr = pd.crosstab(df1[i], df2['Attrition'], margins=True,
                      )
    dfr['YesToNo'] = round((dfr['Yes'] / dfr['No'])*100, 2)
    dfr['YesOverTot'] = round((dfr['Yes'] / dfr['All'])*100, 2)
    dfr.drop(labels=['All'], axis=0, inplace=True)
    dfrtop = dfr.head(3).sort_values('YesOverTot', ascending=False)
    dfrbot = dfr.tail(3).sort_values('YesOverTot', ascending=False)
    dfrmer = [dfrtop, dfrbot]
    display(
        pd.concat(dfrmer)
        # pd.crosstab(df1[i], df1['Attrition'], margins=True,
    )

# --
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'JobInvolvement',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'NumCompaniesWorked',
#  'OverTime',
#  'PercentSalaryHike',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany']
# C:\Users\MasterDK-Laptop\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:338: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Attrition  No  Yes  All  YesToNo  YesOverTot
# Age
# 19          3   38   41  1266.67       92.68
# 20          5   31   36   620.00       86.11
# ...

# %%
# Basic heatmap correlation matrix

# %%
from seaborn import clustermap
# Compute the correlation matrix
corr = IBM_HR.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
#f, ax = plt.subplots(figsize=(30, 15))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(240, 180, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.set(font_scale=1.3)
plt.figure(figsize=(24, 20))

sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, annot=True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# death_counts = pd.crosstab([titanic.pclass, titanic.sex], titanic.survived.astype(bool))
"""
# df1 = pd.read_csv('HR-Employee-Attrition.csv')
df1 = pd.read_csv('HR-Attrition-upsampled-cleaned.csv')
x = pd.crosstab([df1["Department"],df1['JobInvolvement']],
                df1['Attrition'], margins=True, normalize=True)*100

y = pd.crosstab([df1["Department"],df1['JobSatisfaction']],
                df1['Attrition'], margins=True, normalize=True)*100
# round(x, 2)

round(y, 2)
"""
# Review cols
df2cols = ['JobInvolvement', 'JobSatisfaction', 
           'OverTime','Gender', 'Education', 
           'EducationField', 'StockOptionLevel',
           'MonthlyIncome',
           'YearsAtCompany']
# --

# -- ITERATE THROUGH THE DATAFRAME AND FIND HIGHEST AND LOWEST RATIOS OF ATTRITION
for i in df2cols:
    dfr = pd.crosstab([df1["Department"], df1[i]], df2['Attrition'], margins=True
                      )
    # dfr['YesToNo'] = round((dfr['Yes'] / dfr['No'])*100, 2)
    dfr['YesOverTot'] = round((dfr['Yes'] / dfr['All'])*100, 2)
    dfr.drop(labels=['All'], axis=0, inplace=True)
    # dfrtop = dfr.head(3).sort_values('YesOverTot', ascending=False)
    # dfrbot = dfr.tail(3).sort_values('YesOverTot', ascending=False)
    # dfrmer = [dfrtop, dfrbot]
    # display(dfm(dfrmer)
        # pd.crosstab(df1[i], df1['Attrition'], margins=True,
    display(dfm(dfr))
# Out:
# C:\Users\MasterDK-Laptop\Anaconda3\lib\site-packages\pandas\core\generic.py:3946: PerformanceWarning:
#
# dropping on a non-lexsorted multi-index without a level parameter may impact performance.
# Attrition                                 No  Yes  All  YesOverTot
# Department               JobInvolvement
# 'Human Resources'        1                 2    8   10       80.00
#                          2                12   25   37       67.57
#                          3                31   30   61       49.18
#                          4                 6    3    9       33.33
# 'Research & Development' 1                39   52   91       57.14
#                          2               208  207  415       49.88
#                          3               484  388  872       44.50
#                          4                97   34  131       25.95
# Sales                    1                14   71   85       83.53
#                          2                84  160  244       65.57
# ...

# %%
x.drop(labels=['All'], axis=0, inplace=True)
x.plot(kind='bar',
       fontsize=22,
       figsize=(20, 10)
       )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-98137df9988d> in <module>
# ----> 1 x.drop(labels=['All'], axis=0, inplace=True)
#       2 x.plot(kind='bar',
#       3        fontsize=22,
#       4        figsize=(20, 10)
#       5        )
#
# NameError: name 'x' is not defined

# %%
df1cols = [i for i in df1.columns]

for i in df1cols:
    display(dfm(df1[i].describe()))
# Out:
#                Age
# count  1470.000000
# mean     36.923810
# std       9.135373
# min      18.000000
# 25%      30.000000
# 50%      36.000000
# 75%      43.000000
# max      60.000000
#        Attrition
# count       1470
# unique         2
# top           No
# freq        1233
#        BusinessTravel
# count            1470
# unique              3
# top     Travel_Rarely
# freq             1043
#                     Department
# count                     1470
# unique                       3
# top     Research & Development
# freq                       961
#        DistanceFromHome
# count       1470.000000
# mean           9.192517
# std            8.106864
# min            1.000000
# 25%            2.000000
# 50%            7.000000
# 75%           14.000000
# max           29.000000
#          Education
# count  1470.000000
# mean      2.912925
# std       1.024165
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max       5.000000
# ...

# %%
IBM_HR = pd.read_csv('HR-Employee-Attrition.csv')
#IBM_HR = pd.read_csv('HR-Attrition-upsampled-cleaned.csv')

# -- DROP COLS FOR PLOTTING
notused = ['DailyRate', 'EmployeeNumber', 'EmployeeCount',
           'MonthlyIncome', 'MonthlyRate', 'Over18'
           # list any Column labels you don't want displayed
           ]
df1 = IBM_HR
for i in notused:
    df1.drop(labels=[i], axis=1,
             inplace=True
             )

# --
# -- PLOT VARIABLES
df1cols = [i for i in df1.columns]
display(df1cols)
for i in df1cols:
    pd.crosstab(df1[i], df1['JobSatisfaction']).plot(kind='bar',
                                                     fontsize=22,
                                                     figsize=(20, 10)
                                                     )
    plt.xlabel(xlabel=i, size=32)


# --

# -- DROP FOR CROSS TABS
"""
notused = ['DailyRate', 'EmployeeNumber', 'EmployeeCount',
           # 'MonthlyIncome',
           'MonthlyRate', 'Over18'
           # list any Column labels you don't want displayed
           ]
"""
df2 = IBM_HR
"""
for i in notused:
    df2.drop(labels=[i], axis=1,
             inplace=True
             )
"""
# Review cols
df2cols = [i for i in df2.columns]
# --

# -- ITERATE THROUGH THE DATAFRAME AND FIND HIGHEST AND LOWEST RATIOS OF ATTRITION
for i in df2cols:
    dfr = pd.crosstab(df1[i], df2['Attrition'], margins=True,
                      )
    dfr['YesToNo'] = round((dfr['Yes'] / dfr['No'])*100, 2)
    dfr['YesOverTot'] = round((dfr['Yes'] / dfr['All'])*100, 2)
    dfr.drop(labels=['All'], axis=0, inplace=True)
    dfrtop = dfr.sort_values('YesOverTot', ascending=False)
    dfrbot = dfr.sort_values('YesOverTot', ascending=False)
    dfrmer = [dfrtop, dfrbot]
    display(
        pd.concat(dfrmer)
        # pd.crosstab(df1[i], df1['Attrition'], margins=True,
    )

# --
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'NumCompaniesWorked',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']
# C:\Users\MasterDK-Laptop\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:338: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# ...

# %%
## Used to determine which variables are highly correlated. Generates list of recomended variables to review/drop.

# %%
hrcordrop = df1

# Threshold for removing correlated variables
threshold = 0.62

# Absolute value correlation matrix
corr_matrix = hrcordrop.corr().abs()
corr_matrix.head()

# Upper triangle of correlations
upper = corr_matrix.where(
    np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper.head()

# Select columns with correlations above threshold
to_drop = [column for column in upper.columns if any(
    upper[column] >= threshold)]

print('There are %d columns to remove :' % (len(to_drop)))

data = hrcordrop.drop(columns=to_drop)

to_drop

# %%
# Feature selection

# Inorder to avoid the Dummy trap, we are removing the less Importance Dummy Varaible columns...
# For this we are using the Random Forest to select the Importance Feature...
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, max_features='sqrt')

# Loading the dataset:
df_feature_imp = feature_imp_Dataset(df)

# Def X and Y for Unscaled Dataset
target_col = ["Attrition"]
y = pd.DataFrame(df_feature_imp,columns=target_col)
#y = df_unscaled["Attrition"]
X = df_feature_imp.drop('Attrition',1)

# Fit the Model with the X and y ...
clf = clf.fit(X, y)
features = pd.DataFrame()
features['feature'] = X.columns
features['importance'] = clf.feature_importances_
features.sort_values(by=['importance'], ascending=True, inplace=True)
features.set_index('feature', inplace=True)
features.plot(kind='barh', figsize=(25, 25))

# %%
dfb = IBM_HR
dfb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
#pd.crosstab([dfb["Education"], dfb['YearsAtCompany'].sum()], dfb['Attrition'], margins=True)
dfm(dfb.groupby("Education")['Age'].mean())
# Out:
#                  Age
# Education
# 1          32.164706
# 2          36.861702
# 3          36.479021
# 4          39.281407
# 5          39.895833

# %%
dfm(dfb.groupby("Education")['YearsAtCompany'].mean())
# Out:
#            YearsAtCompany
# Education
# 1                6.488235
# 2                6.613475
# 3                6.860140
# 4                7.560302
# 5                8.354167

# %%
dfm(dfb.groupby("MaritalStatus")['Age'].mean())
# Out:
#                      Age
# MaritalStatus
# Divorced       37.489297
# Married        37.757801
# Single         35.336170

# %%
dfm(dfb.groupby("MaritalStatus")['YearsAtCompany'].mean())
# Out:
#                YearsAtCompany
# MaritalStatus
# Divorced             7.302752
# Married              7.307578
# Single               6.374468

# %%
dfr2 = pd.crosstab([dfb["JobInvolvement"],
                    dfb['RelationshipSatisfaction']], dfb['Attrition'], margins=True)
dfr2['YesToNo'] = round((dfr2['Yes'] / dfr2['All'])*100, 2)
display(dfm(dfr2))

# %%
pd.crosstab([dfb["JobInvolvement"], dfb['RelationshipSatisfaction']], dfb['Attrition'], margins=True)
# Out:
# Attrition                                  No  Yes   All
# JobInvolvement RelationshipSatisfaction
# 1              1                           13    4    17
#                2                           11    7    18
#                3                           18    7    25
#                4                           13   10    23
# 2              1                           55   18    73
#                2                           68   17    85
#                3                           92   23   115
#                4                           89   13   102
# 3              1                          124   33   157
#                2                          156   20   176
#                3                          239   37   276
#                4                          224   35   259
# 4              1                           27    2    29
#                2                           23    1    24
#                3                           39    4    43
# ...

# %%
dfr2 = pd.crosstab([dfb["RelationshipSatisfaction"],
                    dfb['JobInvolvement']], dfb['Attrition'], margins=True)
dfr2['YesToNo'] = round((dfr2['Yes'] / dfr2['All'])*100, 2)
display(dfm(dfr2))
"""
 dfr = pd.crosstab(df1[i], df2['Attrition'], margins=True,
                      )
    dfr['YesToNo'] = round((dfr['Yes'] / dfr['No'])*100, 2)
    dfr['YesOverTot'] = round((dfr['Yes'] / dfr['All'])*100, 2)
    dfr.drop(labels=['All'], axis=0, inplace=True)
    dfrtop = dfr.sort_values('YesOverTot', ascending=False)
    dfrbot = dfr.sort_values('YesOverTot', ascending=False)
    dfrmer = [dfrtop, dfrbot]
    display(
        pd.concat(dfrmer)"""
# Out:
# Attrition                                  No  Yes   All  YesToNo
# RelationshipSatisfaction JobInvolvement
# 1                        1                 13    4    17    23.53
#                          2                 55   18    73    24.66
#                          3                124   33   157    21.02
#                          4                 27    2    29     6.90
# 2                        1                 11    7    18    38.89
#                          2                 68   17    85    20.00
#                          3                156   20   176    11.36
#                          4                 23    1    24     4.17
# 3                        1                 18    7    25    28.00
#                          2                 92   23   115    20.00
#                          3                239   37   276    13.41
#                          4                 39    4    43     9.30
# 4                        1                 13   10    23    43.48
# ...

# %%
dfr2 = pd.crosstab([dfb["Department"],
                    dfb['JobInvolvement']], dfb['Attrition'], margins=True)
dfr2['YesToNo'] = round((dfr2['Yes'] / dfr2['All'])*100, 2)
display(dfm(dfr2))
# Out:
# Attrition                                No  Yes   All  YesToNo
# Department             JobInvolvement
# Human Resources        1                  2    1     3    33.33
#                        2                 12    5    17    29.41
#                        3                 31    5    36    13.89
#                        4                  6    1     7    14.29
# Research & Development 1                 39   12    51    23.53
#                        2                208   40   248    16.13
#                        3                484   76   560    13.57
#                        4                 97    5   102     4.90
# Sales                  1                 14   15    29    51.72
#                        2                 84   26   110    23.64
#                        3                228   44   272    16.18
#                        4                 28    7    35    20.00
# All                                    1233  237  1470    16.12
